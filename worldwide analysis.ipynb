# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# read csv files

cause_of_death_csv = pd.read_csv("cause_of_deaths.csv")
population_csv = pd.read_csv("POP_TOTAL_DS2_en_v2.csv", skiprows=4)

cause_of_death = pd.DataFrame(cause_of_death_csv)
#cause_of_death_csv
population_csv.head()
# Out:
#   Country Name Country Code     Indicator Name Indicator Code       1960  \
# 0        Aruba          ABW  Population, total    SP.POP.TOTL    54208.0
# 1      Andorra          AND  Population, total    SP.POP.TOTL    13414.0
# 2  Afghanistan          AFG  Population, total    SP.POP.TOTL  8994793.0
# 3       Angola          AGO  Population, total    SP.POP.TOTL  5270844.0
# 4      Albania          ALB  Population, total    SP.POP.TOTL  1608800.0
#
#         1961       1962       1963       1964       1965  ...        2008  \
# 0    55435.0    56226.0    56697.0    57029.0    57360.0  ...    101342.0
# 1    14376.0    15376.0    16410.0    17470.0    18551.0  ...     85616.0
# 2  9164945.0  9343772.0  9531555.0  9728645.0  9935358.0  ...  26528741.0
# 3  5367287.0  5465905.0  5565808.0  5665701.0  5765025.0  ...  19842251.0
# 4  1659800.0  1711319.0  1762621.0  1814135.0  1864791.0  ...   2947314.0
#
#          2009        2010        2011        2012        2013        2014  \
# 0    101416.0    101597.0    101936.0    102393.0    102921.0    103441.0
# 1     85474.0     84419.0     82326.0     79316.0     75902.0     72786.0
# 2  27207291.0  27962207.0  28809167.0  29726803.0  30682500.0  31627506.0
# 3  20520103.0  21219954.0  21942296.0  22685632.0  23448202.0  24227524.0
# 4   2927519.0   2913021.0   2904780.0   2900247.0   2896652.0   2893654.0
#
#          2015  2016  Unnamed: 61
# 0    103889.0   NaN          NaN
# 1     70473.0   NaN          NaN
# 2  32526562.0   NaN          NaN
# 3  25021974.0   NaN          NaN
# 4   2889167.0   NaN          NaN
#
# [5 rows x 62 columns]

# %%
#can we group by continent first? 
countries_continents = pd.read_csv('countries_continents.csv')

del countries_continents['Unnamed: 0']
countries_continents


#merge the two df

cause_of_death = pd.merge(cause_of_death, countries_continents, how = 'left', left_on=['Country/Territory'], right_on=['Country'])
cause_of_death
# Out:
#      Country/Territory Code  Year  Meningitis  \
# 0          Afghanistan  AFG  1990        2159
# 1          Afghanistan  AFG  1991        2218
# 2          Afghanistan  AFG  1992        2475
# 3          Afghanistan  AFG  1993        2812
# 4          Afghanistan  AFG  1994        3027
# ...                ...  ...   ...         ...
# 6115          Zimbabwe  ZWE  2015        1439
# 6116          Zimbabwe  ZWE  2016        1457
# 6117          Zimbabwe  ZWE  2017        1460
# 6118          Zimbabwe  ZWE  2018        1450
# 6119          Zimbabwe  ZWE  2019        1450
#
#       Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 0                                        1116                  371
# 1                                        1136                  374
# 2                                        1162                  378
# 3                                        1187                  384
# 4                                        1211                  391
# ...                                       ...                  ...
# 6115                                      754                  215
# 6116                                      767                  219
# 6117                                      781                  223
# 6118                                      795                  227
# 6119                                      812                  232
#
#       Nutritional Deficiencies  Malaria  Drowning  Interpersonal Violence  \
# 0                         2087       93      1370                    1538
# 1                         2153      189      1391                    2001
# 2                         2441      239      1514                    2299
# 3                         2837      108      1687                    2589
# 4                         3081      211      1809                    2849
# ...                        ...      ...       ...                     ...
# 6115                      3019     2518       770                    1302
# 6116                      3056     2050       801                    1342
# 6117                      2990     2116       818                    1363
# 6118                      2918     2088       825                    1396
# 6119                      2884     2068       827                    1434
#
#       ...  Poisonings  Protein-Energy Malnutrition  Road Injuries  \
# 0     ...         338                         2054           4154
# 1     ...         351                         2119           4472
# 2     ...         386                         2404           5106
# 3     ...         425                         2797           5681
# 4     ...         451                         3038           6001
# ...   ...         ...                          ...            ...
# 6115  ...         381                         2990           2373
# 6116  ...         393                         3027           2436
# 6117  ...         398                         2962           2473
# 6118  ...         400                         2890           2509
# 6119  ...         405                         2855           2554
#
#       Chronic Respiratory Diseases  \
# 0                             5945
# 1                             6050
# 2                             6223
# 3                             6445
# 4                             6664
# ...                            ...
# 6115                          2751
# 6116                          2788
# 6117                          2818
# 6118                          2849
# 6119                          2891
#
#       Cirrhosis and Other Chronic Liver Diseases  Digestive Diseases  \
# 0                                           2673                5005
# 1                                           2728                5120
# 2                                           2830                5335
# 3                                           2943                5568
# 4                                           3027                5739
# ...                                          ...                 ...
# 6115                                        1956                4202
# 6116                                        1962                4264
# 6117                                        2007                4342
# 6118                                        2030                4377
# 6119                                        2065                4437
#
#       Fire, Heat, and Hot Substances  Acute Hepatitis  Continent      Country
# 0                                323             2985       Asia  Afghanistan
# 1                                332             3092       Asia  Afghanistan
# 2                                360             3325       Asia  Afghanistan
# 3                                396             3601       Asia  Afghanistan
# 4                                420             3816       Asia  Afghanistan
# ...                              ...              ...        ...          ...
# 6115                             632              146     Africa     Zimbabwe
# 6116                             648              146     Africa     Zimbabwe
# 6117                             654              144     Africa     Zimbabwe
# 6118                             657              139     Africa     Zimbabwe
# 6119                             662              136     Africa     Zimbabwe
#
# [6120 rows x 36 columns]

# %%
population = pd.DataFrame(population_csv)
population_drop = population.drop(population.iloc[:, 3:34], axis=1)
population_drop.head()
# Out:
#   Country Name Country Code     Indicator Name        1990        1991  \
# 0        Aruba          ABW  Population, total     62148.0     64623.0
# 1      Andorra          AND  Population, total     54511.0     56674.0
# 2  Afghanistan          AFG  Population, total  12067570.0  12789374.0
# 3       Angola          AGO  Population, total  11127870.0  11472173.0
# 4      Albania          ALB  Population, total   3286542.0   3266790.0
#
#          1992        1993        1994        1995        1996  ...  \
# 0     68235.0     72498.0     76700.0     80326.0     83195.0  ...
# 1     58904.0     61003.0     62707.0     63854.0     64291.0  ...
# 2  13745630.0  14824371.0  15869967.0  16772522.0  17481800.0  ...
# 3  11848971.0  12246786.0  12648483.0  13042666.0  13424813.0  ...
# 4   3247039.0   3227287.0   3207536.0   3187784.0   3168033.0  ...
#
#          2008        2009        2010        2011        2012        2013  \
# 0    101342.0    101416.0    101597.0    101936.0    102393.0    102921.0
# 1     85616.0     85474.0     84419.0     82326.0     79316.0     75902.0
# 2  26528741.0  27207291.0  27962207.0  28809167.0  29726803.0  30682500.0
# 3  19842251.0  20520103.0  21219954.0  21942296.0  22685632.0  23448202.0
# 4   2947314.0   2927519.0   2913021.0   2904780.0   2900247.0   2896652.0
#
#          2014        2015  2016  Unnamed: 61
# 0    103441.0    103889.0   NaN          NaN
# 1     72786.0     70473.0   NaN          NaN
# 2  31627506.0  32526562.0   NaN          NaN
# 3  24227524.0  25021974.0   NaN          NaN
# 4   2893654.0   2889167.0   NaN          NaN
#
# [5 rows x 31 columns]

# %%
cleaned_population = population_drop.drop(['2016', 'Unnamed: 61'], axis=1)
cleaned_population.head()
# Out:
#   Country Name Country Code     Indicator Name        1990        1991  \
# 0        Aruba          ABW  Population, total     62148.0     64623.0
# 1      Andorra          AND  Population, total     54511.0     56674.0
# 2  Afghanistan          AFG  Population, total  12067570.0  12789374.0
# 3       Angola          AGO  Population, total  11127870.0  11472173.0
# 4      Albania          ALB  Population, total   3286542.0   3266790.0
#
#          1992        1993        1994        1995        1996  ...  \
# 0     68235.0     72498.0     76700.0     80326.0     83195.0  ...
# 1     58904.0     61003.0     62707.0     63854.0     64291.0  ...
# 2  13745630.0  14824371.0  15869967.0  16772522.0  17481800.0  ...
# 3  11848971.0  12246786.0  12648483.0  13042666.0  13424813.0  ...
# 4   3247039.0   3227287.0   3207536.0   3187784.0   3168033.0  ...
#
#          2006        2007        2008        2009        2010        2011  \
# 0    100830.0    101218.0    101342.0    101416.0    101597.0    101936.0
# 1     83373.0     84878.0     85616.0     85474.0     84419.0     82326.0
# 2  25183615.0  25877544.0  26528741.0  27207291.0  27962207.0  28809167.0
# 3  18541467.0  19183907.0  19842251.0  20520103.0  21219954.0  21942296.0
# 4   2992547.0   2970017.0   2947314.0   2927519.0   2913021.0   2904780.0
#
#          2012        2013        2014        2015
# 0    102393.0    102921.0    103441.0    103889.0
# 1     79316.0     75902.0     72786.0     70473.0
# 2  29726803.0  30682500.0  31627506.0  32526562.0
# 3  22685632.0  23448202.0  24227524.0  25021974.0
# 4   2900247.0   2896652.0   2893654.0   2889167.0
#
# [5 rows x 29 columns]

# %%
population_total = cleaned_population.rename(columns={"Country Name": "Country/Territory"})
population_total.head()
# Out:
#   Country/Territory Country Code     Indicator Name        1990        1991  \
# 0             Aruba          ABW  Population, total     62148.0     64623.0
# 1           Andorra          AND  Population, total     54511.0     56674.0
# 2       Afghanistan          AFG  Population, total  12067570.0  12789374.0
# 3            Angola          AGO  Population, total  11127870.0  11472173.0
# 4           Albania          ALB  Population, total   3286542.0   3266790.0
#
#          1992        1993        1994        1995        1996  ...  \
# 0     68235.0     72498.0     76700.0     80326.0     83195.0  ...
# 1     58904.0     61003.0     62707.0     63854.0     64291.0  ...
# 2  13745630.0  14824371.0  15869967.0  16772522.0  17481800.0  ...
# 3  11848971.0  12246786.0  12648483.0  13042666.0  13424813.0  ...
# 4   3247039.0   3227287.0   3207536.0   3187784.0   3168033.0  ...
#
#          2006        2007        2008        2009        2010        2011  \
# 0    100830.0    101218.0    101342.0    101416.0    101597.0    101936.0
# 1     83373.0     84878.0     85616.0     85474.0     84419.0     82326.0
# 2  25183615.0  25877544.0  26528741.0  27207291.0  27962207.0  28809167.0
# 3  18541467.0  19183907.0  19842251.0  20520103.0  21219954.0  21942296.0
# 4   2992547.0   2970017.0   2947314.0   2927519.0   2913021.0   2904780.0
#
#          2012        2013        2014        2015
# 0    102393.0    102921.0    103441.0    103889.0
# 1     79316.0     75902.0     72786.0     70473.0
# 2  29726803.0  30682500.0  31627506.0  32526562.0
# 3  22685632.0  23448202.0  24227524.0  25021974.0
# 4   2900247.0   2896652.0   2893654.0   2889167.0
#
# [5 rows x 29 columns]

# %%
# Convert to long format
year = list(population_total.columns)[3:]
years = pd.melt(population_total, id_vars=["Country/Territory"], value_vars=year, value_name='Total Population', 
                var_name='Year')
complete = years.sort_values(by=['Country/Territory', 'Year'])
complete.head()
# Out:
#      Country/Territory  Year  Total Population
# 2          Afghanistan  1990        12067570.0
# 266        Afghanistan  1991        12789374.0
# 530        Afghanistan  1992        13745630.0
# 794        Afghanistan  1993        14824371.0
# 1058       Afghanistan  1994        15869967.0

# %%
# Merge data of csv file
death_cause = cause_of_death['Year']=cause_of_death['Year'].astype(str)
merge_data = pd.merge(cause_of_death, complete, on=['Country/Territory', 'Year'], how="left")
# merge_data = pd.merge(cause_of_death, complete, how="left", right_index=True, left_index=True)
death_and_population = merge_data.dropna()
death_and_population
# Out:
#      Country/Territory Code  Year  Meningitis  \
# 0          Afghanistan  AFG  1990        2159
# 1          Afghanistan  AFG  1991        2218
# 2          Afghanistan  AFG  1992        2475
# 3          Afghanistan  AFG  1993        2812
# 4          Afghanistan  AFG  1994        3027
# ...                ...  ...   ...         ...
# 6111          Zimbabwe  ZWE  2011        1803
# 6112          Zimbabwe  ZWE  2012        1586
# 6113          Zimbabwe  ZWE  2013        1448
# 6114          Zimbabwe  ZWE  2014        1422
# 6115          Zimbabwe  ZWE  2015        1439
#
#       Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 0                                        1116                  371
# 1                                        1136                  374
# 2                                        1162                  378
# 3                                        1187                  384
# 4                                        1211                  391
# ...                                       ...                  ...
# 6111                                      722                  211
# 6112                                      724                  209
# 6113                                      731                  209
# 6114                                      741                  212
# 6115                                      754                  215
#
#       Nutritional Deficiencies  Malaria  Drowning  Interpersonal Violence  \
# 0                         2087       93      1370                    1538
# 1                         2153      189      1391                    2001
# 2                         2441      239      1514                    2299
# 3                         2837      108      1687                    2589
# 4                         3081      211      1809                    2849
# ...                        ...      ...       ...                     ...
# 6111                      3013     3479       743                    1222
# 6112                      3095     2763       754                    1243
# 6113                      3017     3544       732                    1241
# 6114                      2977     3685       734                    1257
# 6115                      3019     2518       770                    1302
#
#       ...  Protein-Energy Malnutrition  Road Injuries  \
# 0     ...                         2054           4154
# 1     ...                         2119           4472
# 2     ...                         2404           5106
# 3     ...                         2797           5681
# 4     ...                         3038           6001
# ...   ...                          ...            ...
# 6111  ...                         2983           2335
# 6112  ...                         3065           2328
# 6113  ...                         2987           2289
# 6114  ...                         2948           2302
# 6115  ...                         2990           2373
#
#       Chronic Respiratory Diseases  \
# 0                             5945
# 1                             6050
# 2                             6223
# 3                             6445
# 4                             6664
# ...                            ...
# 6111                          2721
# 6112                          2708
# 6113                          2693
# 6114                          2715
# 6115                          2751
#
#       Cirrhosis and Other Chronic Liver Diseases  Digestive Diseases  \
# 0                                           2673                5005
# 1                                           2728                5120
# 2                                           2830                5335
# 3                                           2943                5568
# 4                                           3027                5739
# ...                                          ...                 ...
# 6111                                        2062                4136
# 6112                                        2011                4132
# 6113                                        1964                4107
# 6114                                        1952                4138
# 6115                                        1956                4202
#
#       Fire, Heat, and Hot Substances  Acute Hepatitis  Continent      Country  \
# 0                                323             2985       Asia  Afghanistan
# 1                                332             3092       Asia  Afghanistan
# 2                                360             3325       Asia  Afghanistan
# 3                                396             3601       Asia  Afghanistan
# 4                                420             3816       Asia  Afghanistan
# ...                              ...              ...        ...          ...
# 6111                             615              152     Africa     Zimbabwe
# 6112                             622              152     Africa     Zimbabwe
# 6113                             612              148     Africa     Zimbabwe
# 6114                             615              146     Africa     Zimbabwe
# 6115                             632              146     Africa     Zimbabwe
#
#       Total Population
# 0           12067570.0
# 1           12789374.0
# 2           13745630.0
# 3           14824371.0
# 4           15869967.0
# ...                ...
# 6111        14255592.0
# 6112        14565482.0
# 6113        14898092.0
# 6114        15245855.0
# 6115        15602751.0
#
# [4231 rows x 37 columns]

# %%
death_and_population
# Out:
#      Country/Territory Code  Year  Meningitis  \
# 0          Afghanistan  AFG  1990        2159
# 1          Afghanistan  AFG  1991        2218
# 2          Afghanistan  AFG  1992        2475
# 3          Afghanistan  AFG  1993        2812
# 4          Afghanistan  AFG  1994        3027
# ...                ...  ...   ...         ...
# 6111          Zimbabwe  ZWE  2011        1803
# 6112          Zimbabwe  ZWE  2012        1586
# 6113          Zimbabwe  ZWE  2013        1448
# 6114          Zimbabwe  ZWE  2014        1422
# 6115          Zimbabwe  ZWE  2015        1439
#
#       Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 0                                        1116                  371
# 1                                        1136                  374
# 2                                        1162                  378
# 3                                        1187                  384
# 4                                        1211                  391
# ...                                       ...                  ...
# 6111                                      722                  211
# 6112                                      724                  209
# 6113                                      731                  209
# 6114                                      741                  212
# 6115                                      754                  215
#
#       Nutritional Deficiencies  Malaria  Drowning  Interpersonal Violence  \
# 0                         2087       93      1370                    1538
# 1                         2153      189      1391                    2001
# 2                         2441      239      1514                    2299
# 3                         2837      108      1687                    2589
# 4                         3081      211      1809                    2849
# ...                        ...      ...       ...                     ...
# 6111                      3013     3479       743                    1222
# 6112                      3095     2763       754                    1243
# 6113                      3017     3544       732                    1241
# 6114                      2977     3685       734                    1257
# 6115                      3019     2518       770                    1302
#
#       ...  Protein-Energy Malnutrition  Road Injuries  \
# 0     ...                         2054           4154
# 1     ...                         2119           4472
# 2     ...                         2404           5106
# 3     ...                         2797           5681
# 4     ...                         3038           6001
# ...   ...                          ...            ...
# 6111  ...                         2983           2335
# 6112  ...                         3065           2328
# 6113  ...                         2987           2289
# 6114  ...                         2948           2302
# 6115  ...                         2990           2373
#
#       Chronic Respiratory Diseases  \
# 0                             5945
# 1                             6050
# 2                             6223
# 3                             6445
# 4                             6664
# ...                            ...
# 6111                          2721
# 6112                          2708
# 6113                          2693
# 6114                          2715
# 6115                          2751
#
#       Cirrhosis and Other Chronic Liver Diseases  Digestive Diseases  \
# 0                                           2673                5005
# 1                                           2728                5120
# 2                                           2830                5335
# 3                                           2943                5568
# 4                                           3027                5739
# ...                                          ...                 ...
# 6111                                        2062                4136
# 6112                                        2011                4132
# 6113                                        1964                4107
# 6114                                        1952                4138
# 6115                                        1956                4202
#
#       Fire, Heat, and Hot Substances  Acute Hepatitis  Continent      Country  \
# 0                                323             2985       Asia  Afghanistan
# 1                                332             3092       Asia  Afghanistan
# 2                                360             3325       Asia  Afghanistan
# 3                                396             3601       Asia  Afghanistan
# 4                                420             3816       Asia  Afghanistan
# ...                              ...              ...        ...          ...
# 6111                             615              152     Africa     Zimbabwe
# 6112                             622              152     Africa     Zimbabwe
# 6113                             612              148     Africa     Zimbabwe
# 6114                             615              146     Africa     Zimbabwe
# 6115                             632              146     Africa     Zimbabwe
#
#       Total Population
# 0           12067570.0
# 1           12789374.0
# 2           13745630.0
# 3           14824371.0
# 4           15869967.0
# ...                ...
# 6111        14255592.0
# 6112        14565482.0
# 6113        14898092.0
# 6114        15245855.0
# 6115        15602751.0
#
# [4231 rows x 37 columns]

# %%
death_and_population.columns[3:-5]
# Out:
# Index(['Meningitis', 'Alzheimer's Disease and Other Dementias',
#        'Parkinson's Disease', 'Nutritional Deficiencies', 'Malaria',
#        'Drowning', 'Interpersonal Violence', 'Maternal Disorders', 'HIV/AIDS',
#        'Drug Use Disorders', 'Tuberculosis', 'Cardiovascular Diseases',
#        'Lower Respiratory Infections', 'Neonatal Disorders',
#        'Alcohol Use Disorders', 'Self-harm', 'Exposure to Forces of Nature',
#        'Diarrheal Diseases', 'Environmental Heat and Cold Exposure',
#        'Neoplasms', 'Conflict and Terrorism', 'Diabetes Mellitus',
#        'Chronic Kidney Disease', 'Poisonings', 'Protein-Energy Malnutrition',
#        'Road Injuries', 'Chronic Respiratory Diseases',
#        'Cirrhosis and Other Chronic Liver Diseases', 'Digestive Diseases'],
#       dtype='object')

# %%
#add a new col for percentage using population values


for disease in death_and_population.columns[3:-5]:
    title = disease + ' Percentage'
    
    death_and_population[title] = (death_and_population[disease] / death_and_population['Total Population']) * 100

death_and_population
# Out:
# C:\Users\panth\AppData\Local\Temp\ipykernel_11252\2753141550.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   death_and_population[title] = (death_and_population[disease] / death_and_population['Total Population']) * 100
# C:\Users\panth\AppData\Local\Temp\ipykernel_11252\2753141550.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   death_and_population[title] = (death_and_population[disease] / death_and_population['Total Population']) * 100
# C:\Users\panth\AppData\Local\Temp\ipykernel_11252\2753141550.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   death_and_population[title] = (death_and_population[disease] / death_and_population['Total Population']) * 100
# C:\Users\panth\AppData\Local\Temp\ipykernel_11252\2753141550.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   death_and_population[title] = (death_and_population[disease] / death_and_population['Total Population']) * 100
# C:\Users\panth\AppData\Local\Temp\ipykernel_11252\2753141550.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   death_and_population[title] = (death_and_population[disease] / death_and_population['Total Population']) * 100
# C:\Users\panth\AppData\Local\Temp\ipykernel_11252\2753141550.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   death_and_population[title] = (death_and_population[disease] / death_and_population['Total Population']) * 100
# C:\Users\panth\AppData\Local\Temp\ipykernel_11252\2753141550.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   death_and_population[title] = (death_and_population[disease] / death_and_population['Total Population']) * 100
# C:\Users\panth\AppData\Local\Temp\ipykernel_11252\2753141550.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   death_and_population[title] = (death_and_population[disease] / death_and_population['Total Population']) * 100
# C:\Users\panth\AppData\Local\Temp\ipykernel_11252\2753141550.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   death_and_population[title] = (death_and_population[disease] / death_and_population['Total Population']) * 100
# C:\Users\panth\AppData\Local\Temp\ipykernel_11252\2753141550.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   death_and_population[title] = (death_and_population[disease] / death_and_population['Total Population']) * 100
# C:\Users\panth\AppData\Local\Temp\ipykernel_11252\2753141550.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   death_and_population[title] = (death_and_population[disease] / death_and_population['Total Population']) * 100
# C:\Users\panth\AppData\Local\Temp\ipykernel_11252\2753141550.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   death_and_population[title] = (death_and_population[disease] / death_and_population['Total Population']) * 100
# C:\Users\panth\AppData\Local\Temp\ipykernel_11252\2753141550.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   death_and_population[title] = (death_and_population[disease] / death_and_population['Total Population']) * 100
# C:\Users\panth\AppData\Local\Temp\ipykernel_11252\2753141550.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   death_and_population[title] = (death_and_population[disease] / death_and_population['Total Population']) * 100
# C:\Users\panth\AppData\Local\Temp\ipykernel_11252\2753141550.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   death_and_population[title] = (death_and_population[disease] / death_and_population['Total Population']) * 100
# C:\Users\panth\AppData\Local\Temp\ipykernel_11252\2753141550.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   death_and_population[title] = (death_and_population[disease] / death_and_population['Total Population']) * 100
# C:\Users\panth\AppData\Local\Temp\ipykernel_11252\2753141550.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   death_and_population[title] = (death_and_population[disease] / death_and_population['Total Population']) * 100
# C:\Users\panth\AppData\Local\Temp\ipykernel_11252\2753141550.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   death_and_population[title] = (death_and_population[disease] / death_and_population['Total Population']) * 100
# C:\Users\panth\AppData\Local\Temp\ipykernel_11252\2753141550.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   death_and_population[title] = (death_and_population[disease] / death_and_population['Total Population']) * 100
# C:\Users\panth\AppData\Local\Temp\ipykernel_11252\2753141550.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   death_and_population[title] = (death_and_population[disease] / death_and_population['Total Population']) * 100
# C:\Users\panth\AppData\Local\Temp\ipykernel_11252\2753141550.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   death_and_population[title] = (death_and_population[disease] / death_and_population['Total Population']) * 100
# C:\Users\panth\AppData\Local\Temp\ipykernel_11252\2753141550.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   death_and_population[title] = (death_and_population[disease] / death_and_population['Total Population']) * 100
# C:\Users\panth\AppData\Local\Temp\ipykernel_11252\2753141550.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   death_and_population[title] = (death_and_population[disease] / death_and_population['Total Population']) * 100
# C:\Users\panth\AppData\Local\Temp\ipykernel_11252\2753141550.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   death_and_population[title] = (death_and_population[disease] / death_and_population['Total Population']) * 100
# C:\Users\panth\AppData\Local\Temp\ipykernel_11252\2753141550.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   death_and_population[title] = (death_and_population[disease] / death_and_population['Total Population']) * 100
# C:\Users\panth\AppData\Local\Temp\ipykernel_11252\2753141550.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   death_and_population[title] = (death_and_population[disease] / death_and_population['Total Population']) * 100
# C:\Users\panth\AppData\Local\Temp\ipykernel_11252\2753141550.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   death_and_population[title] = (death_and_population[disease] / death_and_population['Total Population']) * 100
# C:\Users\panth\AppData\Local\Temp\ipykernel_11252\2753141550.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   death_and_population[title] = (death_and_population[disease] / death_and_population['Total Population']) * 100
# C:\Users\panth\AppData\Local\Temp\ipykernel_11252\2753141550.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   death_and_population[title] = (death_and_population[disease] / death_and_population['Total Population']) * 100
#      Country/Territory Code  Year  Meningitis  \
# 0          Afghanistan  AFG  1990        2159
# 1          Afghanistan  AFG  1991        2218
# 2          Afghanistan  AFG  1992        2475
# 3          Afghanistan  AFG  1993        2812
# 4          Afghanistan  AFG  1994        3027
# ...                ...  ...   ...         ...
# 6111          Zimbabwe  ZWE  2011        1803
# 6112          Zimbabwe  ZWE  2012        1586
# 6113          Zimbabwe  ZWE  2013        1448
# 6114          Zimbabwe  ZWE  2014        1422
# 6115          Zimbabwe  ZWE  2015        1439
#
#       Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 0                                        1116                  371
# 1                                        1136                  374
# 2                                        1162                  378
# 3                                        1187                  384
# 4                                        1211                  391
# ...                                       ...                  ...
# 6111                                      722                  211
# 6112                                      724                  209
# 6113                                      731                  209
# 6114                                      741                  212
# 6115                                      754                  215
#
#       Nutritional Deficiencies  Malaria  Drowning  Interpersonal Violence  \
# 0                         2087       93      1370                    1538
# 1                         2153      189      1391                    2001
# 2                         2441      239      1514                    2299
# 3                         2837      108      1687                    2589
# 4                         3081      211      1809                    2849
# ...                        ...      ...       ...                     ...
# 6111                      3013     3479       743                    1222
# 6112                      3095     2763       754                    1243
# 6113                      3017     3544       732                    1241
# 6114                      2977     3685       734                    1257
# 6115                      3019     2518       770                    1302
#
#       ...  Neoplasms Percentage  Conflict and Terrorism Percentage  \
# 0     ...              0.095960                           0.012347
# 1     ...              0.092233                           0.026350
# 2     ...              0.088886                           0.031603
# 3     ...              0.085225                           0.027630
# 4     ...              0.081374                           0.056453
# ...   ...                   ...                                ...
# 6111  ...              0.072715                           0.000035
# 6112  ...              0.071772                           0.000069
# 6113  ...              0.070976                           0.000054
# 6114  ...              0.071213                           0.000033
# 6115  ...              0.071532                           0.000083
#
#       Diabetes Mellitus Percentage  Chronic Kidney Disease Percentage  \
# 0                         0.017468                           0.030735
# 1                         0.016576                           0.029118
# 2                         0.015663                           0.027471
# 3                         0.014807                           0.026052
# 4                         0.014058                           0.024776
# ...                            ...                                ...
# 6111                      0.020673                           0.014016
# 6112                      0.020391                           0.013759
# 6113                      0.020184                           0.013512
# 6114                      0.020294                           0.013492
# 6115                      0.020355                           0.013510
#
#       Poisonings Percentage  Protein-Energy Malnutrition Percentage  \
# 0                  0.002801                                0.017021
# 1                  0.002744                                0.016568
# 2                  0.002808                                0.017489
# 3                  0.002867                                0.018868
# 4                  0.002842                                0.019143
# ...                     ...                                     ...
# 6111               0.002511                                0.020925
# 6112               0.002513                                0.021043
# 6113               0.002430                                0.020050
# 6114               0.002407                                0.019336
# 6115               0.002442                                0.019163
#
#       Road Injuries Percentage  Chronic Respiratory Diseases Percentage  \
# 0                     0.034423                                 0.049264
# 1                     0.034967                                 0.047305
# 2                     0.037146                                 0.045273
# 3                     0.038322                                 0.043476
# 4                     0.037814                                 0.041991
# ...                        ...                                      ...
# 6111                  0.016380                                 0.019087
# 6112                  0.015983                                 0.018592
# 6113                  0.015364                                 0.018076
# 6114                  0.015099                                 0.017808
# 6115                  0.015209                                 0.017632
#
#       Cirrhosis and Other Chronic Liver Diseases Percentage  \
# 0                                              0.022150
# 1                                              0.021330
# 2                                              0.020588
# 3                                              0.019852
# 4                                              0.019074
# ...                                                 ...
# 6111                                           0.014464
# 6112                                           0.013807
# 6113                                           0.013183
# 6114                                           0.012803
# 6115                                           0.012536
#
#       Digestive Diseases Percentage
# 0                          0.041475
# 1                          0.040033
# 2                          0.038812
# 3                          0.037560
# 4                          0.036163
# ...                             ...
# 6111                       0.029013
# 6112                       0.028368
# 6113                       0.027567
# 6114                       0.027142
# 6115                       0.026931
#
# [4231 rows x 66 columns]

# %%
death_and_population.head()
# Out:
#   Country/Territory Code  Year  Meningitis  \
# 0       Afghanistan  AFG  1990        2159
# 1       Afghanistan  AFG  1991        2218
# 2       Afghanistan  AFG  1992        2475
# 3       Afghanistan  AFG  1993        2812
# 4       Afghanistan  AFG  1994        3027
#
#    Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 0                                     1116                  371
# 1                                     1136                  374
# 2                                     1162                  378
# 3                                     1187                  384
# 4                                     1211                  391
#
#    Nutritional Deficiencies  Malaria  Drowning  Interpersonal Violence  ...  \
# 0                      2087       93      1370                    1538  ...
# 1                      2153      189      1391                    2001  ...
# 2                      2441      239      1514                    2299  ...
# 3                      2837      108      1687                    2589  ...
# 4                      3081      211      1809                    2849  ...
#
#    Neoplasms Percentage  Conflict and Terrorism Percentage  \
# 0              0.095960                           0.012347
# 1              0.092233                           0.026350
# 2              0.088886                           0.031603
# 3              0.085225                           0.027630
# 4              0.081374                           0.056453
#
#    Diabetes Mellitus Percentage  Chronic Kidney Disease Percentage  \
# 0                      0.017468                           0.030735
# 1                      0.016576                           0.029118
# 2                      0.015663                           0.027471
# 3                      0.014807                           0.026052
# 4                      0.014058                           0.024776
#
#    Poisonings Percentage  Protein-Energy Malnutrition Percentage  \
# 0               0.002801                                0.017021
# 1               0.002744                                0.016568
# 2               0.002808                                0.017489
# 3               0.002867                                0.018868
# 4               0.002842                                0.019143
#
#    Road Injuries Percentage  Chronic Respiratory Diseases Percentage  \
# 0                  0.034423                                 0.049264
# 1                  0.034967                                 0.047305
# 2                  0.037146                                 0.045273
# 3                  0.038322                                 0.043476
# 4                  0.037814                                 0.041991
#
#    Cirrhosis and Other Chronic Liver Diseases Percentage  \
# 0                                           0.022150
# 1                                           0.021330
# 2                                           0.020588
# 3                                           0.019852
# 4                                           0.019074
#
#    Digestive Diseases Percentage
# 0                       0.041475
# 1                       0.040033
# 2                       0.038812
# 3                       0.037560
# 4                       0.036163
#
# [5 rows x 66 columns]

# %%
continent_year = death_and_population[death_and_population['Year'] == '1990'].groupby('Continent').count()
continent_year
#repeat for all the continents 
continents = death_and_population.groupby('Continent').sum()
continents
for continent in continents.index:
    #print(continent)
    cause_continent = death_and_population[death_and_population['Continent'] == continent]
    year_continent = cause_continent.groupby('Year').sum()
    plt.plot(year_continent.index, year_continent['Cardiovascular Diseases Percentage'])

plt.legend(continent_year.index)
plt.title('Cardiovascular Diseases vs Year')
plt.ylabel('Cardiovascular Percentage of Population')
plt.xticks(rotation = 90) # Rotates X-Axis Ticks by 45-degrees
plt.show()

# %%
#why does europe have such a high rate of CVD??
country = death_and_population[death_and_population['Continent'] == 'Europe'].groupby('Country/Territory').sum().sort_values('Cardiovascular Diseases Percentage', ascending = False)[['Cardiovascular Diseases Percentage']].head(50)
country
#death_and_population[death_and_population['Continent'] == 'Europe'].sort_values('Cardiovascular Diseases Percentage', ascending = False)[['Country/Territory', 'Year', 'Cardiovascular Diseases Percentage']].head(50)
# Out:
#                         Cardiovascular Diseases Percentage
# Country/Territory
# Bulgaria                                         26.773383
# Ukraine                                          23.340541
# Serbia                                           21.802338
# Latvia                                           20.921537
# Georgia                                          20.909195
# Belarus                                          20.457710
# Romania                                          18.039161
# Moldova                                          17.964447
# Estonia                                          17.801261
# Lithuania                                        17.080410
# Hungary                                          16.666830
# Croatia                                          14.686114
# Monaco                                           14.294270
# Montenegro                                       13.850549
# Poland                                           11.897049
# Sweden                                           11.879798
# Greece                                           11.519849
# Germany                                          11.514986
# Finland                                          11.437733
# Austria                                          11.124080
# Bosnia and Herzegovina                           10.955748
# Armenia                                          10.803825
# Azerbaijan                                       10.239654
# Portugal                                          9.969518
# Italy                                             9.849934
# United Kingdom                                    9.833942
# Denmark                                           9.720392
# Norway                                            9.663559
# Slovenia                                          9.491370
# Belgium                                           8.691526
# Malta                                             8.659044
# Switzerland                                       8.564839
# Luxembourg                                        8.193228
# Spain                                             7.614118
# Ireland                                           7.455045
# Cyprus                                            7.403449
# Netherlands                                       7.330395
# Albania                                           7.284184
# San Marino                                        6.779994
# France                                            6.598390
# Iceland                                           6.452774
# Andorra                                           3.978372
